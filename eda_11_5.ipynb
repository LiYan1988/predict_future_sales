# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import gc
import sys
import time
import gc
import itertools
import tqdm
import time
import copy

import scipy.stats as ss
from numba import jit

if os.name=='nt':
    try:
        mingw_path = 'C:\\Program Files\\mingw-w64\\x86_64-8.1.0-posix-seh-rt_v6-rev0\\mingw64\\bin'
        os.environ['PATH'] = mingw_path + ';' + os.environ['PATH']
    except:
        pass
    
import xgboost as xgb
from sklearn.metrics import mean_squared_error 
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold

# %matplotlib inline

# %% [markdown]
# ### Helper Function

# %%
def lag_features(df, lags, col):
    '''create lag features of col'''
    cols_idx = ['date_block_num', 'shop_id', 'item_id']
    cols_f = ['date_block_num', 'shop_id', 'item_id', col]
    tmp = df.loc[:, cols_f]
    for i in lags:
        shifted = tmp.copy()
        shifted_cols = shifted.columns.tolist()
        shifted_cols[-1] = col+'_lag_'+str(i)
        shifted.columns = shifted_cols
        shifted['date_block_num'] += i
        df = pd.merge(df, shifted, on=cols_idx, how='left')
    return df

# %%
def clip_rmse(preds, dtrain):
    y_test = np.array(dtrain.get_label())
    preds = np.array(preds)
    y_test = np.maximum(np.minimum(y_test, 20), 0)
    preds = np.maximum(np.minimum(preds, 20), 0)
    #preds = np.array(list(map(lambda x: min(20, max(x, 0)), list(preds))))
    #y_test = np.array(list(map(lambda x: min(20, max(x, 0)), list(y_test))))
    rmse = np.sqrt(mean_squared_error(preds,y_test))
    return 'clip-rmse', rmse

# %%
def cv(param, n_repetition, n_split, n_tree, verbose, random_state):
    '''Repeated CV'''
    
    cv_results = {}
    clf = {}
    running_time = {}

    np.random.seed(random_state)

    for m in range(n_repetition):
        # Train and valuation sets split
        skf = StratifiedKFold(n_splits=n_split, random_state=np.random.randint(10**6), shuffle=True)

        for n, (train_index, val_index) in enumerate(skf.split(x_train, y_train)):

            start_time = time.time()

            # Construct DMatrix
            dtrain = xgb.DMatrix(x_train.iloc[train_index], label=y_train.iloc[train_index])
            dval = xgb.DMatrix(x_train.iloc[val_index], label=y_train.iloc[val_index])

            # Placeholder for evals_results
            cv_results[m, n] = {}

            param['seed'] = np.random.randint(10**6)
            clf[m, n] = xgb.train(param, dtrain,num_boost_round=n_tree, 
                                  evals=[(dtrain, 'train'), (dval, 'val')], 
                                  feval=clip_rmse, maximize=False, early_stopping_rounds=None, 
                                  evals_result=cv_results[m, n], verbose_eval=verbose)

            running_time[m, n] = time.time() - start_time

            print('Repeat {}, split {}, val score = {:.3f}, running time = {:.3f} min.'.format(m, n, 
                cv_results[m, n]['val']['clip-rmse'][-1], running_time[m, n]/60))

    cv_results_final = {}
    for m in range(n_repetition):
        for n in range(n_split):
            cv_results_final['train', m, n] = cv_results[m, n]['train']['clip-rmse']
            cv_results_final['val', m, n] = cv_results[m, n]['val']['clip-rmse']

    df = pd.DataFrame(cv_results_final)
    df.index.name = 'iteration'
    df.columns.names = ['dataset', 'repetition', 'cv_split']

    print('Val mean = {:.3f}, std = {:.3f}'.format(df['val'].iloc[-1].mean(), df['val'].iloc[-1].std()))
    
    return df, clf, running_time

# %%
def feature_combination(x, feature_list, function_dict, column_name, merge=False):
    '''Combination of new features'''
    tmp = x.groupby(feature_list).agg(function_dict)
    tmp.columns = column_name
    if merge:
        x = x.merge(tmp, on=feature_list, how='left')
        return x, tmp
    else:
        return tmp

# %% [markdown]
# ### Load Data

# %%
# Load data
train = pd.read_csv('all/sales_train.csv.gz')
test = pd.read_csv('all/test.csv.gz')
shop = pd.read_csv('all/shops-translated.csv')
item = pd.read_csv('all/item_category.csv')

test.set_index('ID', inplace=True)
item.drop(['item_name_translated'], axis=1, inplace=True)
shop.drop(['Name'], axis=1, inplace=True)

le = LabelEncoder()
item['item_cat1'] = le.fit_transform(item['item_cat1'].astype(str))
item['item_cat2'] = le.fit_transform(item['item_cat2'].astype(str))
shop['City'] = le.fit_transform(shop['City'])
shop['Type'] = le.fit_transform(shop['Type'])

# %%
# Add date_block_num to test 
test['date_block_num'] = 34
test = test[['date_block_num', 'shop_id', 'item_id']]

# %%
train = train.merge(shop, on='shop_id', how='left')
train = train.merge(item, on='item_id', how='left')
train['revenue'] = train.item_price * train.item_cnt_day

# %% [markdown]
# ### Experiments

# %%
x = train.groupby(['date_block_num', 
                   'shop_id', 
                   'item_id']).agg({
    'item_price':[np.mean, np.std], 'item_cnt_day': np.sum, 'revenue': np.sum})
# x.columns = ['price_mean_month', 'cnt_sum_month']

#cols = ['price_mean_month', 'price_median_month', 'price_std_month', 'cnt_sum_month']
cols = ['price_mean_month', 'price_std_month', 'cnt_sum_month', 'rev_sum_month']
x.columns = cols

x.reset_index(inplace=True)
x = pd.concat((x, test), sort=False, ignore_index=True)
x.reset_index(drop=True, inplace=True)

x = pd.merge(x, shop, on='shop_id', how='left')
x = pd.merge(x, item, on='item_id', how='left')

# %%
tmp = x.columns.tolist()
tmp[3:3] = ['City', 'Type', 'item_cat1', 'item_cat2']
tmp = tmp[:11]
x = x[tmp]

# %% [markdown]
# #### Create combinations of features

# %% [markdown]
# ##### `(item_id, Type)`
#
# - count of shops with the same type and selling the same item, i.e., having the same `(item_id, Type)`
# - average sales count among these shops

# %%
feature_list = ['date_block_num', 'item_id', 'Type']
function_list = {'cnt_sum_month':['count', 'mean'], 'price_mean_month':np.mean, 'rev_sum_month':np.mean}
column_name = ['shop_count_item_type', 'cnt_mean_item_type', 'price_mean_item_type', 'rev_mean_item_type']
cols.extend(column_name)
x, tmp = feature_combination(x, feature_list, function_list, column_name, merge=True)

# %% [markdown]
# ##### `(item_id, City)`

# %%
feature_list = ['date_block_num', 'item_id', 'City']
function_list = {'cnt_sum_month':['count', 'mean'], 'price_mean_month':np.mean, 'rev_sum_month':np.mean}
column_name = ['shop_count_item_city', 'cnt_mean_item_city', 'price_mean_item_city', 'rev_mean_item_city']
cols.extend(column_name)
x, tmp = feature_combination(x, feature_list, function_list, column_name, merge=True)

# %% [markdown]
# ##### `(cat1, shop)`

# %%
feature_list = ['date_block_num', 'item_cat1', 'shop_id']
function_list = {'cnt_sum_month':['count', 'mean'], 'price_mean_month':np.mean, 'rev_sum_month':np.mean}
column_name = ['shop_count_cat1_shop', 'cnt_mean_cat1_shop', 'price_mean_cat1_shop', 'rev_mean_cat1_shop']
cols.extend(column_name)
x, tmp = feature_combination(x, feature_list, function_list, column_name, merge=True)

# %% [markdown]
# ##### `(cat1, City)`

# %%
feature_list = ['date_block_num', 'item_cat1', 'City']
function_list = {'cnt_sum_month':['count', 'mean'], 'price_mean_month':np.mean, 'rev_sum_month':np.mean}
column_name = ['shop_count_cat1_city', 'cnt_mean_cat1_city', 'price_mean_cat1_city', 'rev_mean_cat1_city']
cols.extend(column_name)
x, tmp = feature_combination(x, feature_list, function_list, column_name, merge=True)

# %% [markdown]
# ##### `(cat1, Type)`

# %%
feature_list = ['date_block_num', 'item_cat1', 'Type']
function_list = {'cnt_sum_month':['count', 'mean'], 'price_mean_month':np.mean, 'rev_sum_month':np.mean}
column_name = ['shop_count_cat1_type', 'cnt_mean_cat1_type', 'price_mean_cat1_type', 'rev_mean_cat1_type']
cols.extend(column_name)
x, tmp = feature_combination(x, feature_list, function_list, column_name, merge=True)

# %% [markdown]
# ##### `(cat2, shop)`

# %%
feature_list = ['date_block_num', 'item_cat2', 'shop_id']
function_list = {'cnt_sum_month':['count', 'mean'], 'price_mean_month':np.mean, 'rev_sum_month':np.mean}
column_name = ['shop_count_cat2_shop', 'cnt_mean_cat2_shop', 'price_mean_cat2_shop', 'rev_mean_cat2_shop']
cols.extend(column_name)
x, tmp = feature_combination(x, feature_list, function_list, column_name, merge=True)

# %% [markdown]
# ##### `(cat2, city)`

# %%
feature_list = ['date_block_num', 'item_cat2', 'City']
function_list = {'cnt_sum_month':['count', 'mean'], 'price_mean_month':np.mean, 'rev_sum_month':np.mean}
column_name = ['shop_count_cat2_city', 'cnt_mean_cat2_city', 'price_mean_cat2_city', 'rev_mean_cat2_city']
cols.extend(column_name)
x, tmp = feature_combination(x, feature_list, function_list, column_name, merge=True)

# %% [markdown]
# ##### `(cat2, type)`

# %%
feature_list = ['date_block_num', 'item_cat2', 'Type']
function_list = {'cnt_sum_month':['count', 'mean'], 'price_mean_month':np.mean, 'rev_sum_month':np.mean}
column_name = ['shop_count_cat2_type', 'cnt_mean_cat2_type', 'price_mean_cat2_type', 'rev_mean_cat2_type']
cols.extend(column_name)
x, tmp = feature_combination(x, feature_list, function_list, column_name, merge=True)

# %% [markdown]
# ##### `(cat1, cat2)`

# %%
feature_list = ['date_block_num', 'item_cat1', 'item_cat2']
function_list = {'cnt_sum_month':['count', 'mean'], 'price_mean_month':np.mean, 'rev_sum_month':np.mean}
column_name = ['shop_count_cat1_cat2', 'cnt_mean_cat1_cat2', 'price_mean_cat1_cat2', 'rev_mean_cat1_cat2']
cols.extend(column_name)
x, tmp = feature_combination(x, feature_list, function_list, column_name, merge=True)

# %% [markdown]
# ##### `(city, type)`

# %%
feature_list = ['date_block_num', 'City', 'Type']
function_list = {'cnt_sum_month':['count', 'mean'], 'price_mean_month':np.mean, 'rev_sum_month':np.mean}
column_name = ['shop_count_city_type', 'cnt_mean_city_type', 'price_mean_city_type', 'rev_mean_city_type']
cols.extend(column_name)
x, tmp = feature_combination(x, feature_list, function_list, column_name, merge=True)

# %% [markdown]
# #### Write a function for the analysis

# %%
x.tail()
# Out:
#          date_block_num  shop_id  item_id  City  Type  item_cat1  item_cat2  \
# 1823319              34       45    18454    15     4         12         16
# 1823320              34       45    16188    15     4         10         12
# 1823321              34       45    15757    15     4         12         16
# 1823322              34       45    19648    15     4          3         23
# 1823323              34       45      969    15     4          3          9
#
#          price_mean_month  price_std_month  cnt_sum_month         ...          \
# 1823319               NaN              NaN            NaN         ...
# 1823320               NaN              NaN            NaN         ...
# 1823321               NaN              NaN            NaN         ...
# 1823322               NaN              NaN            NaN         ...
# 1823323               NaN              NaN            NaN         ...
#
#          price_mean_cat2_type  rev_mean_cat2_type  shop_count_cat1_cat2  \
# 1823319                   NaN                 NaN                     0
# 1823320                   NaN                 NaN                     0
# 1823321                   NaN                 NaN                     0
# 1823322                   NaN                 NaN                     0
# 1823323                   NaN                 NaN                     0
#
#          cnt_mean_cat1_cat2  price_mean_cat1_cat2  rev_mean_cat1_cat2  \
# 1823319                 NaN                   NaN                 NaN
# 1823320                 NaN                   NaN                 NaN
# 1823321                 NaN                   NaN                 NaN
# 1823322                 NaN                   NaN                 NaN
# 1823323                 NaN                   NaN                 NaN
#
#          shop_count_city_type  cnt_mean_city_type  price_mean_city_type  \
# 1823319                     0                 NaN                   NaN
# 1823320                     0                 NaN                   NaN
# 1823321                     0                 NaN                   NaN
# 1823322                     0                 NaN                   NaN
# 1823323                     0                 NaN                   NaN
#
#          rev_mean_city_type
# 1823319                 NaN
# 1823320                 NaN
# 1823321                 NaN
# 1823322                 NaN
# 1823323                 NaN
#
# [5 rows x 51 columns]

# %%
for c in tqdm.tqdm_notebook(cols):
    x = lag_features(x, range(1, 3), c)
# Out:
# HBox(children=(IntProgress(value=0, max=44), HTML(value='')))

# %%
cols.remove('cnt_sum_month')
x.drop(cols, axis=1, inplace=True)

# %% [markdown]
# #### CV

# %%
# Split train and test sets
x_train = x.loc[x['date_block_num']<=33, :].copy()
x_test = x.loc[x['date_block_num']==34, :].copy()

# Drop target from test set
x_test.drop(['cnt_sum_month'], axis=1, inplace=True)

# Split target from train set
# Note that target is first clipped to (0, 40), then clipped to (0, 20) in test set. 
# This is similar to the idea of calibration
y_train = x_train['cnt_sum_month'].clip(0, 40)
x_train.drop(['cnt_sum_month'], axis=1, inplace=True)

# %%
param = {'max_depth':9, 
         'subsample':0.9,
         'min_child_weight':3,
         'eta':0.03, 
         'lambda':2,
         'colsample_bytree':0.6,
         'seed':1,
         'silent':1,
         'maximize': False,
         'nthread':8}

n_tree = 100
verbose = True

n_split = 5
n_repetition = 2

df, clf, running_time = cv(param, n_repetition, n_split, n_tree, verbose, 42)
# Out:
# [0]	train-rmse:3.64565	val-rmse:3.65052	train-clip-rmse:2.94016	val-clip-rmse:2.94299
# [1]	train-rmse:3.5955	val-rmse:3.60141	train-clip-rmse:2.88998	val-clip-rmse:2.89353
# [2]	train-rmse:3.54715	val-rmse:3.55382	train-clip-rmse:2.84179	val-clip-rmse:2.8458
# [3]	train-rmse:3.50142	val-rmse:3.5091	train-clip-rmse:2.79647	val-clip-rmse:2.80115
# [4]	train-rmse:3.45679	val-rmse:3.46532	train-clip-rmse:2.75256	val-clip-rmse:2.75779
# [34]	train-rmse:2.73274	val-rmse:2.76629	train-clip-rmse:2.10676	val-clip-rmse:2.12606
# [35]	train-rmse:2.72195	val-rmse:2.75633	train-clip-rmse:2.09874	val-clip-rmse:2.11846
# [36]	train-rmse:2.71063	val-rmse:2.74564	train-clip-rmse:2.0902	val-clip-rmse:2.1103
# [37]	train-rmse:2.70065	val-rmse:2.73636	train-clip-rmse:2.08303	val-clip-rmse:2.1035
# [38]	train-rmse:2.69097	val-rmse:2.72732	train-clip-rmse:2.07606	val-clip-rmse:2.09684
# [39]	train-rmse:2.6821	val-rmse:2.71931	train-clip-rmse:2.06968	val-clip-rmse:2.09095
# [40]	train-rmse:2.67301	val-rmse:2.71099	train-clip-rmse:2.06329	val-clip-rmse:2.08494
# [41]	train-rmse:2.66479	val-rmse:2.7035	train-clip-rmse:2.05754	val-clip-rmse:2.07959
# [42]	train-rmse:2.65721	val-rmse:2.69647	train-clip-rmse:2.0523	val-clip-rmse:2.0747
# [43]	train-rmse:2.6492	val-rmse:2.68911	train-clip-rmse:2.04674	val-clip-rmse:2.06948
# [44]	train-rmse:2.64173	val-rmse:2.68237	train-clip-rmse:2.0417	val-clip-rmse:2.06481
# [45]	train-rmse:2.6343	val-rmse:2.67551	train-clip-rmse:2.03644	val-clip-rmse:2.05989
# [46]	train-rmse:2.62741	val-rmse:2.66899	train-clip-rmse:2.03181	val-clip-rmse:2.05548
# [47]	train-rmse:2.62094	val-rmse:2.6632	train-clip-rmse:2.02761	val-clip-rmse:2.05168
# [48]	train-rmse:2.61452	val-rmse:2.65737	train-clip-rmse:2.02338	val-clip-rmse:2.04784
# [49]	train-rmse:2.60808	val-rmse:2.65156	train-clip-rmse:2.01918	val-clip-rmse:2.04396
# [50]	train-rmse:2.60215	val-rmse:2.64631	train-clip-rmse:2.01534	val-clip-rmse:2.0405
# [51]	train-rmse:2.59661	val-rmse:2.64151	train-clip-rmse:2.01178	val-clip-rmse:2.03732
# [52]	train-rmse:2.59174	val-rmse:2.63729	train-clip-rmse:2.0086	val-clip-rmse:2.03452
# [53]	train-rmse:2.58587	val-rmse:2.63204	train-clip-rmse:2.00473	val-clip-rmse:2.03094
# [54]	train-rmse:2.58098	val-rmse:2.62775	train-clip-rmse:2.00164	val-clip-rmse:2.02814
# [55]	train-rmse:2.57633	val-rmse:2.62352	train-clip-rmse:1.99881	val-clip-rmse:2.02552
# [56]	train-rmse:2.57136	val-rmse:2.61915	train-clip-rmse:1.99558	val-clip-rmse:2.0226
# [57]	train-rmse:2.56679	val-rmse:2.61533	train-clip-rmse:1.99258	val-clip-rmse:2.02007
# [58]	train-rmse:2.56253	val-rmse:2.61158	train-clip-rmse:1.99006	val-clip-rmse:2.01781
# [59]	train-rmse:2.5584	val-rmse:2.60801	train-clip-rmse:1.98758	val-clip-rmse:2.01563
# [60]	train-rmse:2.55478	val-rmse:2.60497	train-clip-rmse:1.98551	val-clip-rmse:2.01382
# [61]	train-rmse:2.55138	val-rmse:2.60227	train-clip-rmse:1.98341	val-clip-rmse:2.01208
# [47]	train-rmse:2.62843	val-rmse:2.65508	train-clip-rmse:2.03182	val-clip-rmse:2.05024
# [48]	train-rmse:2.62216	val-rmse:2.64937	train-clip-rmse:2.02762	val-clip-rmse:2.04651
# [49]	train-rmse:2.61589	val-rmse:2.64381	train-clip-rmse:2.02343	val-clip-rmse:2.04272
# [50]	train-rmse:2.60765	val-rmse:2.63642	train-clip-rmse:2.01754	val-clip-rmse:2.0373
# [51]	train-rmse:2.60242	val-rmse:2.63175	train-clip-rmse:2.01425	val-clip-rmse:2.03442
# [52]	train-rmse:2.59692	val-rmse:2.62672	train-clip-rmse:2.01059	val-clip-rmse:2.03108
# [53]	train-rmse:2.59123	val-rmse:2.62166	train-clip-rmse:2.00681	val-clip-rmse:2.0277
# [54]	train-rmse:2.58613	val-rmse:2.61709	train-clip-rmse:2.0034	val-clip-rmse:2.02467
# [55]	train-rmse:2.58153	val-rmse:2.61315	train-clip-rmse:2.00052	val-clip-rmse:2.02229
# [56]	train-rmse:2.57727	val-rmse:2.60939	train-clip-rmse:1.99796	val-clip-rmse:2.02003
# [57]	train-rmse:2.57316	val-rmse:2.60571	train-clip-rmse:1.99554	val-clip-rmse:2.018
# [58]	train-rmse:2.56907	val-rmse:2.60225	train-clip-rmse:1.99314	val-clip-rmse:2.01606
# [59]	train-rmse:2.56525	val-rmse:2.59899	train-clip-rmse:1.99082	val-clip-rmse:2.01413
# [60]	train-rmse:2.56059	val-rmse:2.59485	train-clip-rmse:1.98808	val-clip-rmse:2.01177
# [61]	train-rmse:2.55596	val-rmse:2.59139	train-clip-rmse:1.9852	val-clip-rmse:2.00962
# [62]	train-rmse:2.55215	val-rmse:2.58835	train-clip-rmse:1.983	val-clip-rmse:2.00791
# [63]	train-rmse:2.54855	val-rmse:2.58548	train-clip-rmse:1.98086	val-clip-rmse:2.00628
# [64]	train-rmse:2.54483	val-rmse:2.58222	train-clip-rmse:1.97852	val-clip-rmse:2.00434
# [65]	train-rmse:2.5415	val-rmse:2.57939	train-clip-rmse:1.97645	val-clip-rmse:2.00262
# [66]	train-rmse:2.53729	val-rmse:2.57579	train-clip-rmse:1.97391	val-clip-rmse:2.00049
# [67]	train-rmse:2.53441	val-rmse:2.57349	train-clip-rmse:1.97232	val-clip-rmse:1.99928
# [68]	train-rmse:2.53099	val-rmse:2.57066	train-clip-rmse:1.97019	val-clip-rmse:1.99752
# [69]	train-rmse:2.52822	val-rmse:2.56844	train-clip-rmse:1.96862	val-clip-rmse:1.99628
# [70]	train-rmse:2.52489	val-rmse:2.56583	train-clip-rmse:1.96682	val-clip-rmse:1.99487
# [71]	train-rmse:2.52245	val-rmse:2.56387	train-clip-rmse:1.96554	val-clip-rmse:1.99394
# [72]	train-rmse:2.5201	val-rmse:2.56193	train-clip-rmse:1.96423	val-clip-rmse:1.9929
# [73]	train-rmse:2.51729	val-rmse:2.55955	train-clip-rmse:1.96255	val-clip-rmse:1.99153
# [74]	train-rmse:2.5146	val-rmse:2.55729	train-clip-rmse:1.96091	val-clip-rmse:1.99023
# [75]	train-rmse:2.50952	val-rmse:2.55285	train-clip-rmse:1.95744	val-clip-rmse:1.98716
# [61]	train-rmse:2.54432	val-rmse:2.61036	train-clip-rmse:1.97728	val-clip-rmse:2.02044
# [62]	train-rmse:2.54055	val-rmse:2.60695	train-clip-rmse:1.97498	val-clip-rmse:2.01831
# [63]	train-rmse:2.53632	val-rmse:2.60365	train-clip-rmse:1.97243	val-clip-rmse:2.01622
# [64]	train-rmse:2.5326	val-rmse:2.60067	train-clip-rmse:1.97027	val-clip-rmse:2.01448
# [65]	train-rmse:2.52882	val-rmse:2.59748	train-clip-rmse:1.96799	val-clip-rmse:2.01253
# [66]	train-rmse:2.52561	val-rmse:2.59485	train-clip-rmse:1.9662	val-clip-rmse:2.01105
# [67]	train-rmse:2.52207	val-rmse:2.59221	train-clip-rmse:1.96411	val-clip-rmse:2.00951
# [68]	train-rmse:2.51923	val-rmse:2.58987	train-clip-rmse:1.96255	val-clip-rmse:2.00821
# [69]	train-rmse:2.51596	val-rmse:2.58727	train-clip-rmse:1.96078	val-clip-rmse:2.00677
# [70]	train-rmse:2.51327	val-rmse:2.58507	train-clip-rmse:1.95909	val-clip-rmse:2.00542
# [71]	train-rmse:2.51062	val-rmse:2.58289	train-clip-rmse:1.95755	val-clip-rmse:2.00409
# [72]	train-rmse:2.50798	val-rmse:2.58068	train-clip-rmse:1.95594	val-clip-rmse:2.00277
# [73]	train-rmse:2.50491	val-rmse:2.57817	train-clip-rmse:1.95418	val-clip-rmse:2.00128
# [74]	train-rmse:2.50267	val-rmse:2.57653	train-clip-rmse:1.95292	val-clip-rmse:2.00041
# [75]	train-rmse:2.50018	val-rmse:2.57447	train-clip-rmse:1.95155	val-clip-rmse:1.99924
# [76]	train-rmse:2.49783	val-rmse:2.57246	train-clip-rmse:1.95034	val-clip-rmse:1.99816
# [77]	train-rmse:2.49409	val-rmse:2.56927	train-clip-rmse:1.94788	val-clip-rmse:1.99605
# [78]	train-rmse:2.49076	val-rmse:2.56667	train-clip-rmse:1.94581	val-clip-rmse:1.99433
# [79]	train-rmse:2.48791	val-rmse:2.56427	train-clip-rmse:1.94408	val-clip-rmse:1.99285
# [80]	train-rmse:2.48549	val-rmse:2.56218	train-clip-rmse:1.94277	val-clip-rmse:1.9917
# [81]	train-rmse:2.48297	val-rmse:2.56028	train-clip-rmse:1.94131	val-clip-rmse:1.9906
# [82]	train-rmse:2.48096	val-rmse:2.55867	train-clip-rmse:1.94028	val-clip-rmse:1.98976
# [83]	train-rmse:2.47841	val-rmse:2.55657	train-clip-rmse:1.93874	val-clip-rmse:1.98846
# [84]	train-rmse:2.4751	val-rmse:2.55394	train-clip-rmse:1.93654	val-clip-rmse:1.98666
# [85]	train-rmse:2.47306	val-rmse:2.5524	train-clip-rmse:1.93543	val-clip-rmse:1.98578
# [86]	train-rmse:2.47117	val-rmse:2.55107	train-clip-rmse:1.93439	val-clip-rmse:1.98504
# [87]	train-rmse:2.46936	val-rmse:2.54977	train-clip-rmse:1.93347	val-clip-rmse:1.98436
# [88]	train-rmse:2.46734	val-rmse:2.54841	train-clip-rmse:1.93232	val-clip-rmse:1.98358
# [89]	train-rmse:2.46555	val-rmse:2.54696	train-clip-rmse:1.93121	val-clip-rmse:1.98275
# [75]	train-rmse:2.50297	val-rmse:2.55345	train-clip-rmse:1.95426	val-clip-rmse:1.98083
# [76]	train-rmse:2.50041	val-rmse:2.55132	train-clip-rmse:1.95272	val-clip-rmse:1.97952
# [77]	train-rmse:2.49664	val-rmse:2.54809	train-clip-rmse:1.95025	val-clip-rmse:1.97736
# [78]	train-rmse:2.49444	val-rmse:2.54631	train-clip-rmse:1.94896	val-clip-rmse:1.97632
# [79]	train-rmse:2.49127	val-rmse:2.54392	train-clip-rmse:1.94709	val-clip-rmse:1.97491
# [80]	train-rmse:2.48897	val-rmse:2.54211	train-clip-rmse:1.94576	val-clip-rmse:1.97382
# [81]	train-rmse:2.48684	val-rmse:2.54034	train-clip-rmse:1.94459	val-clip-rmse:1.97284
# [82]	train-rmse:2.48479	val-rmse:2.53877	train-clip-rmse:1.94345	val-clip-rmse:1.97194
# [83]	train-rmse:2.4829	val-rmse:2.53722	train-clip-rmse:1.94234	val-clip-rmse:1.97103
# [84]	train-rmse:2.4793	val-rmse:2.53394	train-clip-rmse:1.93993	val-clip-rmse:1.96881
# [85]	train-rmse:2.47723	val-rmse:2.53229	train-clip-rmse:1.93872	val-clip-rmse:1.96784
# [86]	train-rmse:2.47572	val-rmse:2.53109	train-clip-rmse:1.93788	val-clip-rmse:1.9671
# [87]	train-rmse:2.47359	val-rmse:2.52946	train-clip-rmse:1.93659	val-clip-rmse:1.96618
# [88]	train-rmse:2.47168	val-rmse:2.52791	train-clip-rmse:1.93555	val-clip-rmse:1.96528
# [89]	train-rmse:2.4696	val-rmse:2.52627	train-clip-rmse:1.93433	val-clip-rmse:1.96431
# [90]	train-rmse:2.46819	val-rmse:2.52519	train-clip-rmse:1.9336	val-clip-rmse:1.96378
# [91]	train-rmse:2.46657	val-rmse:2.52401	train-clip-rmse:1.93258	val-clip-rmse:1.96304
# [92]	train-rmse:2.46328	val-rmse:2.52123	train-clip-rmse:1.9304	val-clip-rmse:1.9613
# [93]	train-rmse:2.45992	val-rmse:2.5188	train-clip-rmse:1.92828	val-clip-rmse:1.95984
# [94]	train-rmse:2.45666	val-rmse:2.51586	train-clip-rmse:1.92601	val-clip-rmse:1.95784
# [95]	train-rmse:2.45511	val-rmse:2.51463	train-clip-rmse:1.92518	val-clip-rmse:1.95719
# [96]	train-rmse:2.45375	val-rmse:2.51359	train-clip-rmse:1.92438	val-clip-rmse:1.95659
# [97]	train-rmse:2.45218	val-rmse:2.51243	train-clip-rmse:1.92345	val-clip-rmse:1.95586
# [98]	train-rmse:2.45083	val-rmse:2.51148	train-clip-rmse:1.92266	val-clip-rmse:1.95528
# [99]	train-rmse:2.4492	val-rmse:2.51022	train-clip-rmse:1.92169	val-clip-rmse:1.9545
# Repeat 0, split 3, val score = 1.954, running time = 7.393 min.
# [0]	train-rmse:3.64667	val-rmse:3.64296	train-clip-rmse:2.94063	val-clip-rmse:2.93842
# [1]	train-rmse:3.59579	val-rmse:3.59319	train-clip-rmse:2.88966	val-clip-rmse:2.8885
# [2]	train-rmse:3.54743	val-rmse:3.5459	train-clip-rmse:2.84149	val-clip-rmse:2.84134
# [31]	train-rmse:2.77496	val-rmse:2.80039	train-clip-rmse:2.1373	val-clip-rmse:2.15979
# [32]	train-rmse:2.76255	val-rmse:2.78876	train-clip-rmse:2.12804	val-clip-rmse:2.15105
# [33]	train-rmse:2.75045	val-rmse:2.77733	train-clip-rmse:2.11886	val-clip-rmse:2.14228
# [34]	train-rmse:2.73833	val-rmse:2.76608	train-clip-rmse:2.10969	val-clip-rmse:2.13365
# [35]	train-rmse:2.72676	val-rmse:2.75531	train-clip-rmse:2.10108	val-clip-rmse:2.1255
# [36]	train-rmse:2.716	val-rmse:2.74532	train-clip-rmse:2.09319	val-clip-rmse:2.11796
# [37]	train-rmse:2.70523	val-rmse:2.73549	train-clip-rmse:2.08521	val-clip-rmse:2.11056
# [38]	train-rmse:2.69581	val-rmse:2.72671	train-clip-rmse:2.07849	val-clip-rmse:2.10425
# [39]	train-rmse:2.68549	val-rmse:2.71739	train-clip-rmse:2.0712	val-clip-rmse:2.09759
# [40]	train-rmse:2.67651	val-rmse:2.70918	train-clip-rmse:2.06491	val-clip-rmse:2.09175
# [41]	train-rmse:2.66665	val-rmse:2.7005	train-clip-rmse:2.05799	val-clip-rmse:2.08554
# [42]	train-rmse:2.65887	val-rmse:2.69344	train-clip-rmse:2.05257	val-clip-rmse:2.08053
# [43]	train-rmse:2.65112	val-rmse:2.68625	train-clip-rmse:2.04732	val-clip-rmse:2.0756
# [44]	train-rmse:2.6431	val-rmse:2.67915	train-clip-rmse:2.04181	val-clip-rmse:2.07071
# [45]	train-rmse:2.63588	val-rmse:2.67256	train-clip-rmse:2.03695	val-clip-rmse:2.06618
# [46]	train-rmse:2.62887	val-rmse:2.66621	train-clip-rmse:2.03219	val-clip-rmse:2.06186
# [47]	train-rmse:2.62165	val-rmse:2.65979	train-clip-rmse:2.02738	val-clip-rmse:2.0575
# [48]	train-rmse:2.61542	val-rmse:2.65413	train-clip-rmse:2.02324	val-clip-rmse:2.05375
# [49]	train-rmse:2.60889	val-rmse:2.64846	train-clip-rmse:2.01879	val-clip-rmse:2.04985
# [50]	train-rmse:2.60168	val-rmse:2.64202	train-clip-rmse:2.01391	val-clip-rmse:2.04548
# [51]	train-rmse:2.59602	val-rmse:2.63722	train-clip-rmse:2.01036	val-clip-rmse:2.04251
# [52]	train-rmse:2.58937	val-rmse:2.63112	train-clip-rmse:2.00583	val-clip-rmse:2.03829
# [53]	train-rmse:2.5849	val-rmse:2.6273	train-clip-rmse:2.00301	val-clip-rmse:2.03586
# [54]	train-rmse:2.57989	val-rmse:2.62298	train-clip-rmse:1.99988	val-clip-rmse:2.03312
# [55]	train-rmse:2.5741	val-rmse:2.61818	train-clip-rmse:1.99615	val-clip-rmse:2.03
# [56]	train-rmse:2.5683	val-rmse:2.61302	train-clip-rmse:1.9923	val-clip-rmse:2.02663
# [57]	train-rmse:2.56291	val-rmse:2.60863	train-clip-rmse:1.98874	val-clip-rmse:2.02376
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-0b9d0fe68dbb> in <module>()
#      16 n_repetition = 2
#      17
# ---> 18 df, clf, running_time = cv(param, n_repetition, n_split, n_tree, verbose, 42)
#
# <ipython-input-4-90754071e236> in cv(param, n_repetition, n_split, n_tree, verbose, random_state)
#      27                                   evals=[(dtrain, 'train'), (dval, 'val')],
#      28                                   feval=clip_rmse, maximize=False, early_stopping_rounds=None,
# ---> 29                                   evals_result=cv_results[m, n], verbose_eval=verbose)
#      30
#      31             running_time[m, n] = time.time() - start_time
#
# ~\Anaconda3\envs\kaggle\lib\site-packages\xgboost-0.72-py3.6.egg\xgboost\training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates)
#     202                            evals=evals,
#     203                            obj=obj, feval=feval,
# --> 204                            xgb_model=xgb_model, callbacks=callbacks)
#     205
#     206
#
# ~\Anaconda3\envs\kaggle\lib\site-packages\xgboost-0.72-py3.6.egg\xgboost\training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      72         # Skip the first update if it is a recovery step.
#      73         if version % 2 == 0:
# ---> 74             bst.update(dtrain, i, obj)
#      75             bst.save_rabit_checkpoint()
#      76             version += 1
#
# ~\Anaconda3\envs\kaggle\lib\site-packages\xgboost-0.72-py3.6.egg\xgboost\core.py in update(self, dtrain, iteration, fobj)
#     895         if fobj is None:
#     896             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle, ctypes.c_int(iteration),
# --> 897                                                     dtrain.handle))
#     898         else:
#     899             pred = self.predict(dtrain)
#
# KeyboardInterrupt:

# %%
x_train.tail()
# Out:
#          date_block_num  shop_id  item_id  City  Type  item_cat1  item_cat2  \
# 1609119              33       59    22087    27     1          7         60
# 1609120              33       59    22088    27     1          7         60
# 1609121              33       59    22091    27     1          7         60
# 1609122              33       59    22100    27     1          2          3
# 1609123              33       59    22102    27     1          2          3
#
#          price_mean_month_lag_1  price_mean_month_lag_2  \
# 1609119                   119.0                   119.0
# 1609120                   119.0                   119.0
# 1609121                   179.0                     NaN
# 1609122                   629.0                     NaN
# 1609123                     NaN                  1250.0
#
#          price_std_month_lag_1            ...             \
# 1609119                    0.0            ...
# 1609120                    NaN            ...
# 1609121                    0.0            ...
# 1609122                    NaN            ...
# 1609123                    NaN            ...
#
#          rev_mean_cat1_cat2_lag_1  rev_mean_cat1_cat2_lag_2  \
# 1609119                389.940825                387.652653
# 1609120                389.940825                387.652653
# 1609121                389.940825                       NaN
# 1609122               3722.749814                       NaN
# 1609123                       NaN               3218.079588
#
#          shop_count_city_type_lag_1  shop_count_city_type_lag_2  \
# 1609119                       491.0                       593.0
# 1609120                       491.0                       593.0
# 1609121                       491.0                         NaN
# 1609122                       491.0                         NaN
# 1609123                         NaN                       593.0
#
#          cnt_mean_city_type_lag_1  cnt_mean_city_type_lag_2  \
# 1609119                  1.861507                  2.047218
# 1609120                  1.861507                  2.047218
# 1609121                  1.861507                       NaN
# 1609122                  1.861507                       NaN
# 1609123                       NaN                  2.047218
#
#          price_mean_city_type_lag_1  price_mean_city_type_lag_2  \
# 1609119                 1136.382939                    894.9442
# 1609120                 1136.382939                    894.9442
# 1609121                 1136.382939                         NaN
# 1609122                 1136.382939                         NaN
# 1609123                         NaN                    894.9442
#
#          rev_mean_city_type_lag_1  rev_mean_city_type_lag_2
# 1609119               2233.918534               1684.612142
# 1609120               2233.918534               1684.612142
# 1609121               2233.918534                       NaN
# 1609122               2233.918534                       NaN
# 1609123                       NaN               1684.612142
#
# [5 rows x 95 columns]
